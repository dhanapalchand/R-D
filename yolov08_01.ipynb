# %% [markdown]
# <a href="https://colab.research.google.com/github/dhanapalchand/R-D/blob/main/yolov08_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !nvidia-smi
# Out:
# Thu Oct 19 00:59:41 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.105.17   Driver Version: 525.105.17   CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   52C    P8    12W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 644.5/644.5 kB 12.4 MB/s eta 0:00:00
# ...

# %%
# Pip install method (recommended)

# !pip install ultralytics==8.0.20

from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 26.9/78.2 GB disk)

# %%
from ultralytics import YOLO

from IPython.display import display, Image

# %%
# %cd /content/drive/MyDrive/Colab Notebooks
# Out:
# /content/drive/MyDrive/Colab Notebooks

# %%
# !yolo task=detect mode=train model=yolov8x.pt data=data.yaml epochs=40 imgsz=640 plots=True
# Out:
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !yolo task=detect mode=train model=yolov8n.pt data=data.yaml epochs=48 imgsz=640 plots=True
# Out:
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !yolo task=detect mode=train model=yolov8s.pt data=data.yaml epochs=48 imgsz=640 plots=True
# Out:
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# %cd /content/drive/MyDrive/Colab Notebooks
# Out:
# /content/drive/MyDrive/Colab Notebooks

# %%
# !yolo task=detect \
mode=val \
model= runs/detect/train20/weights/best.pt \
data=data.yaml
# Out:
# /bin/bash: line 1: yolo: command not found

# %%
# !yolo task=detect \
mode=predict \
model=runs/detect/train10/weights/best.pt \
conf=0.25 \
source=01.jpg
# Out:
# 2023-10-12 06:51:00.997728: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-10-12 06:51:01.885521: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 11125971 parameters, 0 gradients, 28.4 GFLOPs
# image 1/1 /content/drive/MyDrive/Colab Notebooks/01.jpg: 384x640 2 dangers, 75.2ms
# Speed: 0.7ms pre-process, 75.2ms inference, 134.4ms postprocess per image at shape (1, 3, 640, 640)

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# !yolo predict save = True model=runs/detect/train20/weights/best.pt source='03.jpg'
# Out:
# 2023-10-19 01:12:38.474782: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-10-19 01:12:39.358563: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 268 layers, 68125494 parameters, 0 gradients, 257.4 GFLOPs
# image 1/1 /content/drive/MyDrive/Colab Notebooks/03.jpg: 640x640 3 dangers, 97.4ms
# Speed: 0.8ms pre-process, 97.4ms inference, 314.1ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict8

# %%
# %pip install ultralytics
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 26.7/78.2 GB disk)

# %%
# !yolo predict model=yolov8n.pt source='https://ultralytics.com/images/bus.jpg'
# Out:
# 2023-09-21 04:38:34.347322: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8n summary (fused): 168 layers, 3151904 parameters, 0 gradients, 8.7 GFLOPs
# ...
# 100% 476k/476k [00:00<00:00, 58.7MB/s]
# image 1/1 /content/drive/MyDrive/Colab Notebooks/bus.jpg: 640x480 4 persons, 1 bus, 1 stop sign, 65.0ms
# Speed: 0.7ms pre-process, 65.0ms inference, 108.0ms postprocess per image at shape (1, 3, 640, 640)

# %%
yolo task=detect mode=predict model=runs/detect/train2/weights/best.pt conf=0.25 source=data/test/images

# %%
# !yolo task=detect mode=predict model=runs/detect/train7/weights/best.pt conf=0.25  source='1000.jpg'
# Out:
# Traceback (most recent call last):
#   File "/usr/local/bin/yolo", line 8, in <module>
#     sys.exit(entrypoint())
#   File "/usr/local/lib/python3.10/dist-packages/ultralytics/yolo/cfg/__init__.py", line 230, in entrypoint
#     model = YOLO(model)
#   File "/usr/local/lib/python3.10/dist-packages/ultralytics/yolo/engine/model.py", line 60, in __init__
#     {'.pt': self._load, '.yaml': self._new}[suffix](model)
#   File "/usr/local/lib/python3.10/dist-packages/ultralytics/yolo/engine/model.py", line 90, in _load
#     self.model, self.ckpt = attempt_load_one_weight(weights)
#   File "/usr/local/lib/python3.10/dist-packages/ultralytics/nn/tasks.py", line 384, in attempt_load_one_weight
#     ckpt = torch_safe_load(weight)  # load ckpt
#   File "/usr/local/lib/python3.10/dist-packages/ultralytics/nn/tasks.py", line 332, in torch_safe_load
#     return torch.load(file, map_location='cpu')  # load
# ...

# %%
# Load YOLOv8n, train it on COCO128 for 3 epochs and predict an image with it
from ultralytics import YOLO

model = YOLO('yolov8x.pt')  # load a pretrained YOLOv8n detection model
model.train(data='data.yaml', epochs=3)  # train the model
model('1000.jpg')  #
# Out:
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-31-62d4b4011467> in <cell line: 5>()
#       3
#       4 model = YOLO('yolov8x.pt')  # load a pretrained YOLOv8n detection model
# ----> 5 model.train(data='data.yaml', epochs=3)  # train the model
#       6 model('1000.jpg')  #
#
# /usr/local/lib/python3.10/dist-packages/ultralytics/yolo/engine/model.py in train(self, **kwargs)
#     201             overrides["resume"] = self.ckpt_path
#     202
# --> 203         self.trainer = self.TrainerClass(overrides=overrides)
#     204         if not overrides.get("resume"):  # manually set model only if not resuming
#     205             self.trainer.model = self.trainer.get_model(weights=self.model if self.ckpt else None, cfg=self.model.yaml)
#
# ...

# %%
# !yolo predict model=runs/detect/train3/weights/best.pt source='1000.jpg'
# Out:
# 2023-09-21 04:29:55.924873: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 268 layers, 68124531 parameters, 0 gradients, 257.4 GFLOPs
# image 1/1 /content/drive/MyDrive/Colab Notebooks/1000.jpg: 640x480 3 danger_positions, 116.3ms
# Speed: 0.9ms pre-process, 116.3ms inference, 175.6ms postprocess per image at shape (1, 3, 640, 640)

# %%
# !yolo task=detect mode=predict model=runs/detect/train2/weights/best.pt conf=0.25 source='1000.jpg'
# Out:
# 2023-09-21 04:36:37.438915: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 268 layers, 68124531 parameters, 0 gradients, 257.4 GFLOPs
# image 1/1 /content/drive/MyDrive/Colab Notebooks/1000.jpg: 640x480 3 danger_positions, 157.2ms
# Speed: 0.7ms pre-process, 157.2ms inference, 158.7ms postprocess per image at shape (1, 3, 640, 640)

# %%
# !yolo task=detect \
mode=train \
model=yolov8s.pt \
data=data.yaml \
epochs=100 \
imgsz=640
# Out:
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !yolo task=detect \
mode=val \
model=runs/detect/train5/weights/best.pt \
conf=0.25 \
source=data.yaml
# Out:
# WARNING ⚠️ 'data' is missing. Using default 'data=coco128.yaml'.
# 2023-09-21 05:01:46.382364: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 11125971 parameters, 0 gradients, 28.4 GFLOPs
# val: Scanning /content/datasets/coco128/labels/train2017.cache... 126 images, 2 backgrounds, 0 corrupt: 100% 128/128 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 8/8 [00:01<00:00,  4.17it/s]
#                    all        128        929    0.00685    0.00505    0.00566    0.00453
# Speed: 0.2ms pre-process, 7.6ms inference, 0.0ms loss, 1.6ms post-process per image

# %%
# !yolo task=detect \
mode=val \
model= runs/detect/train20/weights/best.pt \
data=data.yaml
# Out:
# 2023-10-18 05:12:38.376961: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-10-18 05:12:39.528363: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 268 layers, 68125494 parameters, 0 gradients, 257.4 GFLOPs
# val: Scanning /content/drive/MyDrive/Colab Notebooks/data/train/labels.cache... 90 images, 0 backgrounds, 0 corrupt: 100% 90/90 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 6/6 [00:09<00:00,  1.55s/it]
#                    all         90        234      0.972      0.927      0.967      0.725
# ...

# %%
# !yolo task=detect \
mode=predict \
model=runs/detect/train5/weights/best.pt \
conf=0.25 \
source=01.jpg
# Out:
# 2023-09-21 05:05:26.547635: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 11125971 parameters, 0 gradients, 28.4 GFLOPs
# image 1/1 /content/drive/MyDrive/Colab Notebooks/01.jpg: 384x640 2 danger_positions, 65.2ms
# Speed: 0.7ms pre-process, 65.2ms inference, 93.6ms postprocess per image at shape (1, 3, 640, 640)
